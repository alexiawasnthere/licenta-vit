# %%
from pathlib import Path
import cv2
import matplotlib.pyplot as plt

VIDEO_DIR = Path("data/Train/121")
frame_paths = sorted(VIDEO_DIR.glob("*.jpg"))

plt.ion()
fig, ax = plt.subplots()
ax.axis("off")

for p in frame_paths:
    frame = cv2.imread(str(p))
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    ax.imshow(frame)
    fig.canvas.draw()
    plt.pause(0.5)
    ax.clear()
    ax.axis("off")

plt.ioff()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 17
#      15 ax.imshow(frame)
#      16 fig.canvas.draw()
# ---> 17 plt.pause(0.5)
#      18 ax.clear()
#      19 ax.axis("off")
#
# File ~/miniconda3/envs/licenta-vit/lib/python3.10/site-packages/matplotlib/pyplot.py:759, in pause(interval)
#     757     canvas.start_event_loop(interval)
#     758 else:
# --> 759     time.sleep(interval)
#
# KeyboardInterrupt:

# %%
import numpy as np
from pathlib import Path
import cv2

VIDEO_DIR = Path(r'data/Train/1')
print("Exists:", VIDEO_DIR.exists())
print("Is dir:", VIDEO_DIR.is_dir())
print("Resolved:", VIDEO_DIR.resolve())
print(list(VIDEO_DIR.glob("*")))
# Out:
# Exists: True
# Is dir: True
# Resolved: /home/alexi/licenta/data/Train/1
# ...

# %%
from pathlib import Path
print(Path.home())
# Out:
# /home/alexi
